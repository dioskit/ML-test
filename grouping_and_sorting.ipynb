# %% [markdown]
# <a href="https://colab.research.google.com/github/dioskit/ML-test/blob/main/grouping_and_sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pokipath='/content/Pokemon.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
poke = pd.read_csv(pokipath, index_col = "#")
poke.tail()
# Out:
#                     Name   Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 719              Diancie     Rock  Fairy    600  50     100      150      100
# 719  DiancieMega Diancie     Rock  Fairy    700  50     160      110      160
# 720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60      150
# 720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60      170
# 721            Volcanion     Fire  Water    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 719      150     50           6       True
# 719      110    110           6       True
# 720      130     70           6       True
# 720      130     80           6       True
# 721       90     70           6       True

# %%
poke[['Name','Attack','Defense']].head()
# Out:
#                     Name  Attack  Defense
# #
# 1              Bulbasaur      49       49
# 2                Ivysaur      62       63
# 3               Venusaur      82       83
# 3  VenusaurMega Venusaur     100      123
# 4             Charmander      52       43

# %% [markdown]
# # printing rows

# %%
print(poke.iloc[1:4])
poke.iloc[1,0]
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 'Ivysaur'

# %%
# for index, row in poke.iterrows():
#   print(index, row['Name'])

# %% [markdown]
# # Soting/ DESCRIBING DATA

# %%
# this one will give you the ascending order of Type 1
# and then ascending order of values of HP for each Type 1
print(poke.sort_values(['Type 1','HP'],ascending=True).head(2))

# this means for Type 1 its ascending(1) and desecnding(0) for HP
poke.sort_values(['Type 1','HP'],ascending=[1,0]).head(5)
# Out:
#          Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 292  Shedinja    Bug  Ghost    236   1      90       45       30       30
# 213   Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary
# #
# 292     40           3      False
# 213      5           2      False
#                         Name Type 1    Type 2  Total  HP  Attack  Defense  \
# #
# 469                  Yanmega    Bug    Flying    515  86      76       86
# 637                Volcarona    Bug      Fire    550  85      60       65
# 214                Heracross    Bug  Fighting    500  80     125       75
# 214  HeracrossMega Heracross    Bug  Fighting    600  80     185      115
# 617                 Accelgor    Bug       NaN    495  80      70       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 469      116       56     95           4      False
# 637      135      105    100           5      False
# ...

# %%
#add the stats and store it in new
poke['total'] = poke['HP'] + poke['Attack'] + poke['Defense'] + poke['Sp. Atk'] + poke['Sp. Def'] + poke['Speed']
poke.head(5)
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  total
# #
# 1       65     45           1      False    318
# 2       80     60           1      False    405
# 3      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309
